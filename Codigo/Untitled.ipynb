# %%
import pandas as pd
import numpy as np

# %%
empleados = pd.read_csv('lista_empleados.csv')
empleados.head()
# Out:
#    NUM. EMPLEADO                    NOMBRE       SEXO  \
# 0             16         DIANA LOPEZ TAPIA   Femenino
# 1             32  WENDY JAZMIN VERA ROLDAN   Femenino
# 2             33     JOSE LUIS DIAZ CURIEL  Masculino
# 3             36         ISMAEL CRUZ TAPIA  Masculino
# 4             37  NORMA ELOISA CRUZ OCADIZ   Femenino
#
#                               DEPARTAMENTO          PUESTO
# 0                    SEC. PART. PRESIDENTE  SECRETARIA "A"
# 1    OFICINA DE CONST. Y CERTIF. OFICIALES  SECRETARIA "B"
# 2            DIRECCIÓN DE RASTRO MUNICIPAL        CARGADOR
# 3            DIRECCIÓN DE RASTRO MUNICIPAL        CARGADOR
# 4  DIRECCIÓN DE REGLAMENTOS Y ESPECTACULOS  SECRETARIA "C"

# %%
sexo = empleados.pop('SEXO')
empleados.head()
# Out:
#    NUM. EMPLEADO                    NOMBRE  \
# 0             16         DIANA LOPEZ TAPIA
# 1             32  WENDY JAZMIN VERA ROLDAN
# 2             33     JOSE LUIS DIAZ CURIEL
# 3             36         ISMAEL CRUZ TAPIA
# 4             37  NORMA ELOISA CRUZ OCADIZ
#
#                               DEPARTAMENTO          PUESTO
# 0                    SEC. PART. PRESIDENTE  SECRETARIA "A"
# 1    OFICINA DE CONST. Y CERTIF. OFICIALES  SECRETARIA "B"
# 2            DIRECCIÓN DE RASTRO MUNICIPAL        CARGADOR
# 3            DIRECCIÓN DE RASTRO MUNICIPAL        CARGADOR
# 4  DIRECCIÓN DE REGLAMENTOS Y ESPECTACULOS  SECRETARIA "C"

# %%
num_empleado = int(input('Por favor indique su Num. de Empleado, '))
empleados.loc[empleados['NUM. EMPLEADO'] == num_empleado, 'NOMBRE'].iloc[0]
# Out:
# Por favor indique su Num. de Empleado, 358
# 'JOSE LUIS PEREZ IBARRA'

# %%
num_empleado = int(input())
empleados.loc[empleados['NUM. EMPLEADO'] == num_empleado][['NOMBRE']]

# %%
num_empleado = int(input('Por favor indique su Num. de Empleado, '))
print(f'Bienvenido al Sistema CAS,', empleados.loc[empleados['NUM. EMPLEADO'] == num_empleado,'NOMBRE'].iloc[0])

print("Para Servicios Tecnologicos (1)")
print("Para Redes o Telecomunicacion (2)")
print("Para Desarrollo de TIC's (3)")

reporte_falla = input('Por favor indique la opción deseada: ')

for ST in range(1000):
    
        if(reporte_falla != "1"):
            break
            
        if(reporte_falla == "1"):
            st_contador += 1
                    
        if(st_contador <= 9):
            print("Su Numero de Ticket es")
            print("-----ST000",st_contador,"-----")
            break
        elif(st_contador <= 99):
            print("Su Numero de Ticket es")
            print("-----ST00",st_contador,"-----")
            break
        elif(st_contador <= 999): 
            print("Su Numero de Ticket es")
            print("-----ST0",st_contador,"-----")
            break

prioridad = reporte_falla
if(prioridad == "1"):
    print("Prioridad")
    print("-----A-----")
    print("Tiempo aproximado de espera 10 min")

    
rt_contador = 0

for RT in range(1000):
    
    if(reporte_falla != "2"):
        break
        
    if(reporte_falla == "2"):
        rt_contador += 1 
        
    if(rt_contador <= 9):
        print("Su Numero de Ticket es")
        print("-----RT000",rt_contador,"-----")
        break
    elif(rt_contador <= 99):
        print("Su Numero de Ticket es")
        print("-----RT00",rt_contador,"-----")
        break
    elif(rt_contador <= 999):
        print("Su Numero de Ticket es")
        print("-----RT0",rt_contador,"------")
        break

prioridad = reporte_falla

if(prioridad == "2"):
    print("Prioridad")
    print("-----B-----")
    print("Tiempo aproximado de espera 20 min")
    
dt_contador = 0

for DT in range(1000):
    
    if(reporte_falla != "3"):
        break
        
    if(reporte_falla == "3"):
        dt_contador += 1
        
    if(dt_contador <= 9):
        print("Su Numero de Ticket es")
        print("-----DT000",dt_contador,"-----")
        break
    elif(dt_contador <= 99):
        print("Su Numero de Ticket es")
        print("-----DT00",dt_contador,"-----")
        break
    elif(dt_contador <= 999):
        print("Su Numero de Ticket es")
        print("-----DT0",dt_contador,"-----")
        break

prioridad = reporte_falla

if(prioridad == "3"):
    print("Prioridad")
    print("-----C-----")
    print("Tiempo aproximado de espera 30 min")
# Out:
# Por favor indique su Num. de Empleado, 358
# Bienvenido al Sistema CAS, JOSE LUIS PEREZ IBARRA
# Para Servicios Tecnologicos (1)
# Para Redes o Telecomunicacion (2)
# Para Desarrollo de TIC's (3)
# Por favor indique la opción deseada: 2
# Su Numero de Ticket es
# -----RT000 1 -----
# Prioridad
# -----B-----
# Tiempo aproximado de espera 20 min
